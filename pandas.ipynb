# %% [markdown]
# # Pandas

# %%
import numpy as np
import pandas as pd

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\adity\Downloads\placement.csv")
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
import pandas as pd
df1 = pd.read_excel(r"C:\Users\adity\Downloads\Sort And advnce.xlsx")
df1
# Out:
#               Unnamed: 0      Unnamed: 1    Unnamed: 2     Unnamed: 3  \
# 0                   Sort             NaN           NaN            NaN
# 1                Numbers             NaN           NaN            NaN
# 2                   Text             NaN           NaN            NaN
# 3                  Dates             NaN           NaN            NaN
# 4    MultiColumn Sorting             NaN           NaN            NaN
# ..                   ...             ...           ...            ...
# 101  2021-10-23 00:00:00    Second Class  Matt Abelman  United States
# 102  2020-12-10 00:00:00     First Class     Gene Hale  United States
# 103  2020-12-10 00:00:00     First Class     Gene Hale  United States
# 104  2019-12-31 00:00:00  Standard Class  Steve Nguyen  United States
# 105  2019-12-31 00:00:00  Standard Class  Steve Nguyen  United States
#
#     Unnamed: 4 Unnamed: 5       Unnamed: 6  Unnamed: 7 Unnamed: 8
# ...

# %%
import pandas as pd 
df2 = pd.read_excel(r"C:\Users\adity\Downloads\Sample Data-2.xlsx")

# %%
df2
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0       7981  CA-2016-103800 2016-01-03 2016-01-07  Standard Class
# 1        740  CA-2016-112326 2016-01-04 2016-01-08  Standard Class
# 2        741  CA-2016-112326 2016-01-04 2016-01-08  Standard Class
# 3        742  CA-2016-112326 2016-01-04 2016-01-08  Standard Class
# 4       1760  CA-2016-141817 2016-01-05 2016-01-12  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989     908  CA-2019-143259 2019-12-30 2020-01-03  Standard Class
# 9990     909  CA-2019-143259 2019-12-30 2020-01-03  Standard Class
# 9991    1297  CA-2019-115427 2019-12-30 2020-01-03  Standard Class
# 9992    1298  CA-2019-115427 2019-12-30 2020-01-03  Standard Class
# 9993    5092  CA-2019-156720 2019-12-30 2020-01-03  Standard Class
#
#      Customer ID      Customer Name      Segment Country/Region  \
# 0       DP-13000      Darren Powers     Consumer  United States
# ...

# %%
import pandas as pd 
df3 = pd.read_csv(r"C:\Users\adity\Downloads\SalesData.csv")
df3
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
df.head(2)
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0

# %%
df.tail()
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.head(20)
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# 5   8.77          6.19       1
# 6   5.34          7.09       0
# 7   6.56          6.29       0
# 8   6.32          6.71       0
# 9   7.69          7.12       1
# 10  6.18          6.35       0
# 11  5.44          6.54       0
# 12  6.09          7.01       0
# 13  8.50          5.09       1
# 14  7.51          6.25       1
# 15  8.88          5.93       1
# 16  8.04          7.64       1
# 17  7.81          8.71       1
# 18  5.94          5.88       0
# 19  6.75          8.11       1

# %%
df.count()
# Out:
# cgpa            100
# resume_score    100
# placed          100
# dtype: int64

# %%
df1.count()
# Out:
# Unnamed: 0    88
# Unnamed: 1    71
# Unnamed: 2    64
# Unnamed: 3    72
# Unnamed: 4    64
# Unnamed: 5    48
# Unnamed: 6    47
# Unnamed: 7     0
# Unnamed: 8     8
# dtype: int64

# %%
df2.count()
# Out:
# Row ID            9994
# Order ID          9994
# Order Date        9994
# Ship Date         9994
# Ship Mode         9994
# Customer ID       9994
# Customer Name     9994
# Segment           9994
# Country/Region    9994
# City              9994
# State             9994
# Postal Code       9983
# Region            9994
# Product ID        9994
# Category          9994
# Sub-Category      9994
# Product Name      9994
# Sales             9994
# Quantity          9994
# Discount          9994
# Profit            9994
# dtype: int64

# %%
df3.count()
# Out:
# Region            100
# Country           100
# Item Type         100
# Sales Channel     100
# Order Priority    100
# Order Date        100
# Order ID          100
# Ship Date         100
# Units Sold        100
# Unit Price        100
# Unit Cost         100
# Total Revenue     100
# Total Expense     100
# dtype: int64

# %%
del df

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\adity\Downloads\Titanic-Dataset.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df2.describe()
# Out:
#             Row ID                     Order Date  \
# count  9994.000000                           9994
# mean   4997.500000  2018-04-30 10:03:51.979187456
# min       1.000000            2016-01-03 00:00:00
# 25%    2499.250000            2017-05-23 00:00:00
# 50%    4997.500000            2018-06-26 00:00:00
# 75%    7495.750000            2019-05-14 00:00:00
# max    9994.000000            2019-12-30 00:00:00
# std    2885.163629                            NaN
#
#                            Ship Date   Postal Code         Sales     Quantity  \
# count                           9994   9983.000000   9994.000000  9994.000000
# mean   2018-05-04 09:03:29.645787648  55245.233297    229.858001     3.789574
# min              2016-01-07 00:00:00   1040.000000      0.444000     1.000000
# 25%              2017-05-27 00:00:00  23223.000000     17.280000     2.000000
# 50%              2018-06-29 00:00:00  57103.000000     54.490000     3.000000
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          9994 non-null   int64
#  1   Order ID        9994 non-null   object
#  2   Order Date      9994 non-null   datetime64[ns]
#  3   Ship Date       9994 non-null   datetime64[ns]
#  4   Ship Mode       9994 non-null   object
#  5   Customer ID     9994 non-null   object
#  6   Customer Name   9994 non-null   object
#  7   Segment         9994 non-null   object
#  8   Country/Region  9994 non-null   object
#  9   City            9994 non-null   object
#  10  State           9994 non-null   object
#  11  Postal Code     9983 non-null   float64
#  12  Region          9994 non-null   object
#  13  Product ID      9994 non-null   object
#  14  Category        9994 non-null   object
#  15  Sub-Category    9994 non-null   object
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df2['Category'].value_counts()
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %%
(df['Embarked'].value_counts()).sort_values()
# Out:
# Embarked
# Q     77
# C    168
# S    644
# Name: count, dtype: int64

# %%
(df['Embarked'].value_counts()).sort_values(ascending=False)
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df.sort_values('Embarked')
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 258          259         1       1                           Ward, Miss. Anna
# 125          126         1       3               Nicola-Yarred, Master. Elias
# 354          355         0       3                          Yousif, Mr. Wazli
# 352          353         0       3                         Elias, Mr. Tannous
# 128          129         1       3                          Peter, Miss. Anna
# ..           ...       ...     ...                                        ...
# 355          356         0       3                Vanden Steen, Mr. Leo Peter
# 344          345         0       2                    Fox, Mr. Stanley Hubert
# 445          446         1       1                  Dodge, Master. Washington
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
# ...

# %%
(df.sort_values(['Embarked','Ticket']))
# Out:
#      PassengerId  Survived  Pclass  \
# 366          367         1       1
# 329          330         1       1
# 523          524         1       1
# 889          890         1       1
# 604          605         1       1
# ..           ...       ...     ...
# 219          220         0       2
# 540          541         1       1
# 745          746         0       1
# 61            62         1       1
# 829          830         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 366  Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  female  60.0      1
# 329                      Hippach, Miss. Jean Gertrude  female  16.0      0
# 523   Hippach, Mrs. Louis Albert (Ida Sophia Fischer)  female  44.0      0
# 889                             Behr, Mr. Karl Howell    male  26.0      0
# 604                   Homer, Mr. Harry ("Mr E Haven")    male  35.0      0
# ..                                                ...     ...   ...    ...
# ...

# %%
df.drop_duplicates(subset=['Embarked'])
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 5             6         0       3
# 61           62         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 5                                    Moran, Mr. James    male   NaN      0
# 61                                Icard, Miss. Amelie  female  38.0      0
#
#     Parch     Ticket     Fare Cabin Embarked
# 0       0  A/5 21171   7.2500   NaN        S
# 1       0   PC 17599  71.2833   C85        C
# 5       0     330877   8.4583   NaN        Q
# 61      0     113572  80.0000   B28      NaN

# %%
df.drop_duplicates(subset=['Embarked','Age']).shape
# Out:
# (167, 12)

# %%
df.shape
# Out:
# (891, 12)

# %%
df1 = df.groupby('Embarked')
df1

# %%
len(df)
# Out:
# 891

# %%
len(df1)
# Out:
# 3

# %%
df1.size()
# Out:
# Embarked
# C    168
# Q     77
# S    644
# dtype: int64

# %%
df1.first()
# Out:
#           PassengerId  Survived  Pclass  \
# Embarked
# C                   2         1       1
# Q                   6         0       3
# S                   1         0       3
#
#                                                        Name     Sex   Age  \
# Embarked
# C         Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# Q                                          Moran, Mr. James    male   2.0
# S                                   Braund, Mr. Owen Harris    male  22.0
#
#           SibSp  Parch     Ticket     Fare Cabin
# Embarked
# C             1      0   PC 17599  71.2833   C85
# Q             0      0     330877   8.4583   C78
# S             1      0  A/5 21171   7.2500  C123

# %%
df.head(891)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df["Embarked"]
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.rename(columns={'Sex' : 'Gender'})
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.concat([df,df3])
# Out:
#     PassengerId  Survived  Pclass  \
# 0           1.0       0.0     3.0
# 1           2.0       1.0     1.0
# 2           3.0       1.0     3.0
# 3           4.0       1.0     1.0
# 4           5.0       0.0     3.0
# ..          ...       ...     ...
# 95          NaN       NaN     NaN
# 96          NaN       NaN     NaN
# 97          NaN       NaN     NaN
# 98          NaN       NaN     NaN
# 99          NaN       NaN     NaN
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0    1.0
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                              Heikkinen, Miss. Laina  female  26.0    0.0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 4                            Allen, Mr. William Henry    male  35.0    0.0
# ..                                                ...     ...   ...    ...
# ...

# %%
df.join(df3)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
