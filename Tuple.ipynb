# %%
t1 = (10,20,30,40,50)
print(t1)
# Out:
# (10, 20, 30, 40, 50)

# %%
print(type(t1))
# Out:
# <class 'tuple'>

# %%
print(len(t1))
# Out:
# 5

# %%
t1[3]
# Out:
# 40

# %%
t2 = ("A","D","I","T","Y","A")
print(t2)
# Out:
# ('A', 'D', 'I', 'T', 'Y', 'A')

# %%
t2[4]
# Out:
# 'Y'

# %%
t2[:3]
# Out:
# ('A', 'D', 'I')

# %%
t3 = ("a",)
print(t3)
print(type(t3))
# Out:
# ('a',)
# <class 'tuple'>

# %%
p = [34]
print(p)
print(type(p))
# Out:
# [34]
# <class 'list'>

# %% [markdown]
# ##

# %%
t1[:4]
# Out:
# (10, 20, 30, 40)

# %%
t1[2:4]
# Out:
# (30, 40)

# %%
t2[-4]
# Out:
# 'I'

# %%
t2[-5:-2]
# Out:
# ('D', 'I', 'T')

# %%
t2[::-1]
# Out:
# ('A', 'Y', 'T', 'I', 'D', 'A')

# %%
t1[::-1]
# Out:
# (50, 40, 30, 20, 10)

# %%
t2 = ('A', 'D', 'I', 'T', 'Y', 'A')
y = list(t2)

# %%
print(type(y))
# Out:
# <class 'list'>

# %%
y
# Out:
# ['A', 'D', 'I', 'T', 'Y', 'A']

# %%
y[2]=11

# %%
t2 = tuple(y)

# %%
t2
# Out:
# ('A', 'D', 11, 'T', 'Y', 'A')

# %%
z = list(t2)

# %%
z.append(10)

# %%
z
# Out:
# ['A', 'D', 11, 'T', 'Y', 'A', 10, 10]

# %%
z.remove(10)

# %%
z
# Out:
# ['A', 'D', 11, 'T', 'Y', 'A', 10]

# %%
t2 = tuple(z)

# %%
t2
# Out:
# ('A', 'D', 11, 'T', 'Y', 'A', 10)

# %%
t4 = (78,)
t5 = (32,34,45,65)
t4 = t4 + t5

# %%
t4
# Out:
# (78, 32, 34, 45, 65)

# %%
t6 = t4 +t5

# %%
t6
# Out:
# (78, 32, 34, 45, 65, 32, 34, 45, 65)

# %%
A = list(t2)

# %%
A
# Out:
# ['A', 'D', 11, 'T', 'Y', 'A', 10]

# %%
t2
# Out:
# ('A', 'D', 11, 'T', 'Y', 'A', 10)

# %%
A.remove(11)

# %%
A
# Out:
# ['A', 'D', 'T', 'Y', 'A', 10]

# %%
 t2 = tuple(A)

# %%
t2
# Out:
# ('A', 'D', 'T', 'Y', 'A', 10)

# %%
t7 = (20,34,56,67,78)
t8 = t7*3

# %%
t8
# Out:
# (20, 34, 56, 67, 78, 20, 34, 56, 67, 78, 20, 34, 56, 67, 78)

# %%
t6= (23,)
t7=("s",)
type(t6)
type(t7)
# Out:
# tuple
