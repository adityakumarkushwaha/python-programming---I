# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\adity\Downloads\lpor_classification.csv")

# %%
df.size
# Out:
# 20119

# %%
df.dtypes
# Out:
# Escola                     int64
# Sexo                       int64
# idade                      int64
# TP_Moradia                 int64
# Tamanho_Familia            int64
# Situacao_Pais              int64
# Educacao_Mae               int64
# Educacao_Pai               int64
# Trabalho_Mae               int64
# Trabalho_Pai               int64
# Motivo_Escolha_Escolar     int64
# Responsavel_Legal          int64
# Tempo_ida_Escola           int64
# Tempo_Estudo_Semanal       int64
# Apoio_Educacao_Extra       int64
# Apoio_Educacao_Pais        int64
# Aulas_Particulares         int64
# Ativ_Extracurricular       int64
# Frequentou_Creche          int64
# Quer_Fazer_Graduacao       int64
# Tem_Internet               int64
# Esta_Namorando             int64
# Boa_Convivencia_Familia    int64
# Tempo_Livre_Apos_Escola    int64
# Tempo_com_Amigos           int64
# Alcool_Dia_Util            int64
# Alcool_Fim_Semana          int64
# Estado_Saude               int64
# ...

# %%
np.sum(df['Responsavel_Legal'])
# Out:
# np.int64(235)

# %%
np.mean(df['Responsavel_Legal'])
# Out:
# np.float64(0.362095531587057)

# %%
np.median(df['Responsavel_Legal'])
# Out:
# np.float64(0.0)

# %%
np.std(df['Responsavel_Legal'])
# Out:
# 0.5977713489578508

# %%
np.var(df['Responsavel_Legal'])
# Out:
# 0.35733058563488856

# %%
np.min(df['Responsavel_Legal'])
# Out:
# 0

# %%
np.max(df['Responsavel_Legal'])
# Out:
# 2

# %%
np.percentile(df['Responsavel_Legal'] ,25)
# Out:
# np.float64(0.0)

# %%
np.percentile(df['Responsavel_Legal'] ,75)
# Out:
# np.float64(1.0)

# %%
df.head()
# Out:
#    Escola  Sexo  idade  TP_Moradia  Tamanho_Familia  Situacao_Pais  \
# 0       0     1     18           0                1              1
# 1       0     1     17           0                1              0
# 2       0     1     15           0                0              0
# 3       0     1     15           0                1              0
# 4       0     1     16           0                1              0
#
#    Educacao_Mae  Educacao_Pai  Trabalho_Mae  Trabalho_Pai  ...  \
# 0             4             4             3             0  ...
# 1             1             1             3             4  ...
# 2             1             1             3             4  ...
# 3             4             2             1             2  ...
# 4             3             3             4             4  ...
#
#    Esta_Namorando  Boa_Convivencia_Familia  Tempo_Livre_Apos_Escola  \
# 0               0                        4                        3
# ...

# %%
df.tail()
# Out:
#      Escola  Sexo  idade  TP_Moradia  Tamanho_Familia  Situacao_Pais  \
# 644       1     1     19           1                1              0
# 645       1     1     18           0                0              0
# 646       1     1     18           0                1              0
# 647       1     0     17           0                0              0
# 648       1     0     18           1                0              0
#
#      Educacao_Mae  Educacao_Pai  Trabalho_Mae  Trabalho_Pai  ...  \
# 644             2             3             2             4  ...
# 645             3             1             0             2  ...
# 646             1             1             4             4  ...
# 647             3             1             2             2  ...
# 648             3             2             2             4  ...
#
#      Esta_Namorando  Boa_Convivencia_Familia  Tempo_Livre_Apos_Escola  \
# 644               0                        5                        4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Escola                   649 non-null    int64
#  1   Sexo                     649 non-null    int64
#  2   idade                    649 non-null    int64
#  3   TP_Moradia               649 non-null    int64
#  4   Tamanho_Familia          649 non-null    int64
#  5   Situacao_Pais            649 non-null    int64
#  6   Educacao_Mae             649 non-null    int64
#  7   Educacao_Pai             649 non-null    int64
#  8   Trabalho_Mae             649 non-null    int64
#  9   Trabalho_Pai             649 non-null    int64
#  10  Motivo_Escolha_Escolar   649 non-null    int64
#  11  Responsavel_Legal        649 non-null    int64
#  12  Tempo_ida_Escola         649 non-null    int64
#  13  Tempo_Estudo_Semanal     649 non-null    int64
# ...

# %%
df.shape
# Out:
# (649, 31)

# %%
df.columns
# Out:
# Index(['Escola', 'Sexo', 'idade', 'TP_Moradia', 'Tamanho_Familia',
#        'Situacao_Pais', 'Educacao_Mae', 'Educacao_Pai', 'Trabalho_Mae',
#        'Trabalho_Pai', 'Motivo_Escolha_Escolar', 'Responsavel_Legal',
#        'Tempo_ida_Escola', 'Tempo_Estudo_Semanal', 'Apoio_Educacao_Extra',
#        'Apoio_Educacao_Pais', 'Aulas_Particulares', 'Ativ_Extracurricular',
#        'Frequentou_Creche', 'Quer_Fazer_Graduacao', 'Tem_Internet',
#        'Esta_Namorando', 'Boa_Convivencia_Familia', 'Tempo_Livre_Apos_Escola',
#        'Tempo_com_Amigos', 'Alcool_Dia_Util', 'Alcool_Fim_Semana',
#        'Estado_Saude', 'Falta_Escolar', 'Nota_1Semestre', 'Nota_2Semestre'],
#       dtype='object')

# %%
df.describe()
# Out:
#            Escola        Sexo       idade  TP_Moradia  Tamanho_Familia  \
# count  649.000000  649.000000  649.000000  649.000000       649.000000
# mean     0.348228    0.590139   16.744222    0.303544         0.704160
# std      0.476776    0.492187    1.218138    0.460143         0.456771
# min      0.000000    0.000000   15.000000    0.000000         0.000000
# 25%      0.000000    0.000000   16.000000    0.000000         0.000000
# 50%      0.000000    1.000000   17.000000    0.000000         1.000000
# 75%      1.000000    1.000000   18.000000    1.000000         1.000000
# max      1.000000    1.000000   22.000000    1.000000         1.000000
#
#        Situacao_Pais  Educacao_Mae  Educacao_Pai  Trabalho_Mae  Trabalho_Pai  \
# count     649.000000    649.000000    649.000000    649.000000    649.000000
# mean        0.123267      2.514638      2.306626      2.707242      3.049307
# std         0.328996      1.134552      1.099931      1.348511      1.218696
# ...

# %%
df['Sexo']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 644    1
# 645    1
# 646    1
# 647    0
# 648    0
# Name: Sexo, Length: 649, dtype: int64

# %%
df[['Sexo','Nota_2Semestre']]
# Out:
#      Sexo  Nota_2Semestre
# 0       1              11
# 1       1              11
# 2       1              13
# 3       1              14
# 4       1              13
# ..    ...             ...
# 644     1              11
# 645     1              15
# 646     1              12
# 647     0              10
# 648     0              11
#
# [649 rows x 2 columns]

# %%
df['Nota_2Semestre'].mean()
# Out:
# np.float64(11.570107858243452)

# %%
df['Nota_2Semestre'].median()
# Out:
# 11.0

# %%
df['Nota_2Semestre'].mode()
# Out:
# 0    11
# Name: Nota_2Semestre, dtype: int64

# %%
df.isnull()
# Out:
#      Escola   Sexo  idade  TP_Moradia  Tamanho_Familia  Situacao_Pais  \
# 0     False  False  False       False            False          False
# 1     False  False  False       False            False          False
# 2     False  False  False       False            False          False
# 3     False  False  False       False            False          False
# 4     False  False  False       False            False          False
# ..      ...    ...    ...         ...              ...            ...
# 644   False  False  False       False            False          False
# 645   False  False  False       False            False          False
# 646   False  False  False       False            False          False
# 647   False  False  False       False            False          False
# 648   False  False  False       False            False          False
#
#      Educacao_Mae  Educacao_Pai  Trabalho_Mae  Trabalho_Pai  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# Escola                     0
# Sexo                       0
# idade                      0
# TP_Moradia                 0
# Tamanho_Familia            0
# Situacao_Pais              0
# Educacao_Mae               0
# Educacao_Pai               0
# Trabalho_Mae               0
# Trabalho_Pai               0
# Motivo_Escolha_Escolar     0
# Responsavel_Legal          0
# Tempo_ida_Escola           0
# Tempo_Estudo_Semanal       0
# Apoio_Educacao_Extra       0
# Apoio_Educacao_Pais        0
# Aulas_Particulares         0
# Ativ_Extracurricular       0
# Frequentou_Creche          0
# Quer_Fazer_Graduacao       0
# Tem_Internet               0
# Esta_Namorando             0
# Boa_Convivencia_Familia    0
# Tempo_Livre_Apos_Escola    0
# Tempo_com_Amigos           0
# Alcool_Dia_Util            0
# Alcool_Fim_Semana          0
# Estado_Saude               0
# Falta_Escolar              0
# Nota_1Semestre             0
# Nota_2Semestre             0
# dtype: int64

# %%
df.dropna()
# Out:
#      Escola  Sexo  idade  TP_Moradia  Tamanho_Familia  Situacao_Pais  \
# 0         0     1     18           0                1              1
# 1         0     1     17           0                1              0
# 2         0     1     15           0                0              0
# 3         0     1     15           0                1              0
# 4         0     1     16           0                1              0
# ..      ...   ...    ...         ...              ...            ...
# 644       1     1     19           1                1              0
# 645       1     1     18           0                0              0
# 646       1     1     18           0                1              0
# 647       1     0     17           0                0              0
# 648       1     0     18           1                0              0
#
#      Educacao_Mae  Educacao_Pai  Trabalho_Mae  Trabalho_Pai  ...  \
# 0               4             4             3             0  ...
# ...

# %%
df.fillna(0)
# Out:
#      Escola  Sexo  idade  TP_Moradia  Tamanho_Familia  Situacao_Pais  \
# 0         0     1     18           0                1              1
# 1         0     1     17           0                1              0
# 2         0     1     15           0                0              0
# 3         0     1     15           0                1              0
# 4         0     1     16           0                1              0
# ..      ...   ...    ...         ...              ...            ...
# 644       1     1     19           1                1              0
# 645       1     1     18           0                0              0
# 646       1     1     18           0                1              0
# 647       1     0     17           0                0              0
# 648       1     0     18           1                0              0
#
#      Educacao_Mae  Educacao_Pai  Trabalho_Mae  Trabalho_Pai  ...  \
# 0               4             4             3             0  ...
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 644    False
# 645    False
# 646    False
# 647    False
# 648    False
# Length: 649, dtype: bool

# %%
df.drop_duplicates()
# Out:
#      Escola  Sexo  idade  TP_Moradia  Tamanho_Familia  Situacao_Pais  \
# 0         0     1     18           0                1              1
# 1         0     1     17           0                1              0
# 2         0     1     15           0                0              0
# 3         0     1     15           0                1              0
# 4         0     1     16           0                1              0
# ..      ...   ...    ...         ...              ...            ...
# 644       1     1     19           1                1              0
# 645       1     1     18           0                0              0
# 646       1     1     18           0                1              0
# 647       1     0     17           0                0              0
# 648       1     0     18           1                0              0
#
#      Educacao_Mae  Educacao_Pai  Trabalho_Mae  Trabalho_Pai  ...  \
# 0               4             4             3             0  ...
# ...

# %%
df.sort_values(by='Nota_1Semestre')
# Out:
#      Escola  Sexo  idade  TP_Moradia  Tamanho_Familia  Situacao_Pais  \
# 0         0     1     18           0                1              1
# 569       1     0     18           0                1              0
# 567       1     0     18           1                1              0
# 603       1     1     18           1                0              1
# 605       1     1     19           0                1              0
# ..      ...   ...    ...         ...              ...            ...
# 332       0     1     18           0                1              0
# 344       0     0     18           0                0              0
# 113       0     0     15           0                0              0
# 606       1     1     17           0                1              0
# 617       1     1     18           0                0              0
#
#      Educacao_Mae  Educacao_Pai  Trabalho_Mae  Trabalho_Pai  ...  \
# 0               4             4             3             0  ...
# ...

# %%
df[df['Nota_1Semestre']> 4]
# Out:
#      Escola  Sexo  idade  TP_Moradia  Tamanho_Familia  Situacao_Pais  \
# 1         0     1     17           0                1              0
# 2         0     1     15           0                0              0
# 3         0     1     15           0                1              0
# 4         0     1     16           0                1              0
# 5         0     0     16           0                0              0
# ..      ...   ...    ...         ...              ...            ...
# 644       1     1     19           1                1              0
# 645       1     1     18           0                0              0
# 646       1     1     18           0                1              0
# 647       1     0     17           0                0              0
# 648       1     0     18           1                0              0
#
#      Educacao_Mae  Educacao_Pai  Trabalho_Mae  Trabalho_Pai  ...  \
# 1               1             1             3             4  ...
# ...

# %%
df[(df['Nota_1Semestre']>5)&(df['Nota_2Semestre'] > 6)]
# Out:
#      Escola  Sexo  idade  TP_Moradia  Tamanho_Familia  Situacao_Pais  \
# 1         0     1     17           0                1              0
# 2         0     1     15           0                0              0
# 3         0     1     15           0                1              0
# 4         0     1     16           0                1              0
# 5         0     0     16           0                0              0
# ..      ...   ...    ...         ...              ...            ...
# 644       1     1     19           1                1              0
# 645       1     1     18           0                0              0
# 646       1     1     18           0                1              0
# 647       1     0     17           0                0              0
# 648       1     0     18           1                0              0
#
#      Educacao_Mae  Educacao_Pai  Trabalho_Mae  Trabalho_Pai  ...  \
# 1               1             1             3             4  ...
# ...

# %%
df.groupby('Nota_1Semestre')['Nota_2Semestre'].mean()
# Out:
# Nota_1Semestre
# 0     11.000000
# 4      4.000000
# 5      3.800000
# 6      8.000000
# 7      7.515152
# 8      8.404762
# 9      9.369231
# 10    10.242105
# 11    11.032967
# 12    12.048780
# 13    12.944444
# 14    14.084507
# 15    14.857143
# 16    15.954545
# 17    17.375000
# 18    18.000000
# 19    17.000000
# Name: Nota_2Semestre, dtype: float64

# %%
df.groupby('Nota_1Semestre')['Nota_2Semestre'].median()
# Out:
# Nota_1Semestre
# 0     11.0
# 4      4.0
# 5      5.0
# 6      8.0
# 7      8.0
# 8      9.0
# 9     10.0
# 10    10.0
# 11    11.0
# 12    12.0
# 13    13.0
# 14    14.0
# 15    15.0
# 16    16.0
# 17    17.5
# 18    18.0
# 19    17.0
# Name: Nota_2Semestre, dtype: float64

# %%
plt.hist(df['Nota_1Semestre'] ,bins = 15)
plt.title('First_Semestre')
plt.xlabel('Nota_1Semestre')
plt.ylabel("frequency")
plt.show()

# %%
plt.boxplot(df['Nota_1Semestre'])
plt.title('Nota_1Semestre boxplot')
plt.show()

# %%
plt.scatter(df['Nota_1Semestre'],df['Nota_2Semestre'])
plt.title("Nota_1Semestre vs Nota_2Semestre")
plt.show()

# %%
sns.barplot(data=df,x='Nota_1Semestre',y='Sexo' )
plt.title('Nota_1Semestre vs Sexo ')
plt.show()

# %%
sns.countplot(data=df,x='Sexo')
plt.title("Count_sexo ")
plt.show()

# %%
sns.histplot(data=df,x='Nota_2Semestre',kde=1)
plt.title("Nota_2Semestre ")
plt.show()

# %%
sns.boxplot(data=df,x='Nota_1Semestre' , y = 'Nota_2Semestre',hue='Sexo')
plt.title("Nota_1Semestre vs Nota_2Semestre")
plt.xlabel("First Semestre")
plt.ylabel("Second Semestre")
plt.show()

# %%
sns.violinplot(data=df,x='Nota_1Semestre' , y = 'Sexo')
plt.title('Nota_1Semestre vs Nota_2Semestre')
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
corr = df.corr(numeric_only = 1)
sns.heatmap(corr,cmap='coolwarm')
plt.title("correlation Heatmap")
plt.show()
