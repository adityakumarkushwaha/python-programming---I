# %%
list = [1,2,3,4,5]
print(list)
# Out:
# [1, 2, 3, 4, 5]

# %%
print(list[0])
# Out:
# 1

# %%
print(len(list))
# Out:
# 5

# %%
print(type(list))
# Out:
# <class 'list'>

# %%
print(list[2])
# Out:
# 3

# %%
print(list[-2])
# Out:
# 4

# %%
print(list[2:4])
# Out:
# [3, 4]

# %%
print(list[:3])
# Out:
# [1, 2, 3]

# %%
print(list[2:])
# Out:
# [3, 4, 5]

# %%
print(list[2:5])
# Out:
# [3, 4, 5]

# %%
print(list[-2:])
# Out:
# [4, 5]

# %%
print(list[:-3])
# Out:
# [1, 2]

# %%
print(list[-4:-2])
# Out:
# [2, 3]

# %%
list1 = ["apple","banana","cherry"]
list2 = [1,2,3,4,5,6]
list3 = [True,False,True            ]

# %%
print(list1,list2,list3)
# Out:
# ['apple', 'banana', 'cherry'] [1, 2, 3, 4, 5, 6] [True, False, True]

# %%
list1 = ["apple",34 ,True,40,"mango"]
print(list1)
# Out:
# ['apple', 34, True, 40, 'mango']

# %%
list2 = ["Ram","Shyam","Mohan" ]
print(list2)
# Out:
# ['Ram', 'Shyam', 'Mohan']

# %%
print(list2[2])
# Out:
# Mohan

# %%
print(list2[-2])
# Out:
# Shyam

# %%
print(list2[-1])
# Out:
# Mohan

# %%
print(list2[0:2])
# Out:
# ['Ram', 'Shyam']

# %%
list3 = [2,34,56,78,9990,454]
print(list3)
# Out:
# [2, 34, 56, 78, 9990, 454]

# %%
print(list3[:3])
# Out:
# [2, 34, 56]

# %%
print(list3[2:])
# Out:
# [56, 78, 9990, 454]

# %%
print(list3[2:5])
# Out:
# [56, 78, 9990]

# %%
print(list3[-4:])
# Out:
# [56, 78, 9990, 454]

# %%
print(list3[:-2])
# Out:
# [2, 34, 56, 78]

# %%
print(list3[-3:-1])
# Out:
# [78, 9990]

# %%
list4 = ["aditya","abhishek","aryan"]
print(list4)
# Out:
# ['aditya', 'abhishek', 'aryan']

# %%
list4[1]="ram"
print(list4)
# Out:
# ['aditya', 'ram', 'aryan']

# %%
list4 = [ "aditya","shyam","aryan","ram","abhishek"]
list4[1:3]=["sita","rita"]
print(list4)
# Out:
# ['aditya', 'sita', 'rita', 'ram', 'abhishek']

# %%
list4 = ["aditya","abhishek","aryan"]
list4.append("ram")
print(list4)
# Out:
# ['aditya', 'abhishek', 'aryan', 'ram']

# %%
list4 = ["aditya","abhishek","aryan"]
list4.insert(1, "ram" )
print(list4)
# Out:
# ['aditya', 'ram', 'abhishek', 'aryan']

# %%
list4 = ["aditya","abhishek","aryan"]
list5 = ["ram","sita","rita"]
list4.extend(list5)
print(list4)
# Out:
# ['aditya', 'abhishek', 'aryan', 'ram', 'sita', 'rita']

# %%
list4 = ["aditya","abhishek","aryan"]
list4.remove("aditya")
print(list4)
# Out:
# ['abhishek', 'aryan']

# %%
list4 = ["aditya","abhishek","aryan"]
list4.pop(1)
print(list4)
# Out:
# ['aditya', 'aryan']

# %%
list4 = ["aditya","abhishek","aryan"]
list4.pop()
print(list4)
# Out:
# ['aditya', 'abhishek']

# %%
list4 = ["aditya","abhishek","aryan"]
del list4[0]
print(list4)
# Out:
# ['abhishek', 'aryan']

# %%
list4 = ["aditya","abhishek","aryan"]
del list4[1]
print(list4)
# Out:
# ['aditya', 'aryan']

# %%
list4 =  ["aditya","abhishek","aryan"]
list4.clear()
print(list4)
# Out:
# []

# %%
list4 =  ["aditya","abhishek","aryan"]
for i in list4:
  print(i)
# Out:
# aditya
# abhishek
# aryan

# %%
list4 =   ["aditya","abhishek","aryan"]
for i in range(len(list4)):
  print(list4[i])
# Out:
# aditya
# abhishek
# aryan

# %%
list4 =  ["aditya","abhishek","aryan"]
i = 0
while i < len(list4):
  print(list4[i])
  i=i+1
# Out:
# aditya
# abhishek
# aryan

# %%
list4 =  ["aditya","abhishek","aryan"]
list4.sort()
print(list4)
# Out:
# ['abhishek', 'aditya', 'aryan']

# %%
list5 = [ 35,78,89,764,876,542,98]
list5.sort()
print(list5)
# Out:
# [35, 78, 89, 98, 542, 764, 876]

# %%
list5.sort(reverse = True)
print(list5)
# Out:
# [876, 764, 542, 98, 89, 78, 35]

# %%
list5 = [ 35,78,89,764,876,542,98]
list5.reverse()
print(list5)
# Out:
# [98, 542, 876, 764, 89, 78, 35]

# %%
list5 = [ 35,78,89,764,876,542,98]
list6 = list5.copy()
print(list6)
# Out:
# [35, 78, 89, 764, 876, 542, 98]

# %%
list6 = list(list5)
print(list6)
# Out:
# [35, 78, 89, 764, 876, 542, 98]

# %%
list5 = [ 35,78,89,764,876,542,98]
list6 = list5[:]
print(list6)
# Out:
# [35, 78, 89, 764, 876, 542, 98]
