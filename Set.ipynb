# %%
set1 = {12,13,14,15,16}

# %%
set1
# Out:
# {12, 13, 14, 15, 16, 17}

# %%
print(13 in set1)
# Out:
# True

# %%
print(45 in set1)
# Out:
# False

# %%
print(45 not in set1)
# Out:
# True

# %%
set1.add(17)
set1
# Out:
# {12, 13, 14, 15, 16, 17}

# %%
set2 = {23,24,25,26}
set2
# Out:
# {23, 24, 25, 26}

# %%
set1.update(set2)
set1
# Out:
# {12, 13, 14, 15, 16, 17, 23, 24, 25, 26}

# %%
list1 = ["A","D","I","T","Y","A"]
list1
# Out:
# ['A', 'D', 'I', 'T', 'Y', 'A']

# %%
set1.update(list1)

# %%
set1
# Out:
# {12, 13, 14, 15, 16, 17, 23, 24, 25, 26, 'A', 'D', 'I', 'T', 'Y'}

# %%
set1.remove(25)
set1
# Out:
# {12, 13, 14, 15, 16, 17, 23, 24, 26, 'A', 'D', 'I', 'T', 'Y'}

# %%
set1.discard(26)
set1
# Out:
# {12, 13, 14, 15, 16, 17, 23, 24, 'A', 'D', 'I', 'T', 'Y'}

# %%
set1.pop()
set1
# Out:
# {12, 13, 14, 15, 16, 17, 23, 24, 'A', 'I', 'Y'}

# %%
set3 = {12,34,56,78,93}
set3
# Out:
# {12, 34, 56, 78, 93}

# %%
set3.clear()
set3
# Out:
# set()

# %%
set4 = {768,987,543,878,698} 
set4
# Out:
# {543, 698, 768, 878, 987}

# %%
del set4
set4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 del set4
#       2 set4
#
# NameError: name 'set4' is not defined

# %%
set1 = {12,13,14,15,16}
set1.remove(101)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 2
#       1 set1 = {12,13,14,15,16}
# ----> 2 set1.remove(101)
#
# KeyError: 101

# %%
set1 = {12,13,14,15,16}
set1.discard(101)

# %%
set1 = {"A","D","I","T","Y","A"}
set2 = {12,13,14,15,16}
set3 = set1.union(set2)
print(set3)
# Out:
# {'T', 'D', 'Y', 'I', 12, 13, 14, 15, 16, 'A'}

# %%
set1 = {"A","D","I","T","Y","A"}
set2 = {12,13,14,15,16}
set3 = set1|set2
print(set3)
# Out:
# {'T', 'D', 'Y', 'I', 12, 13, 14, 15, 16, 'A'}

# %%
set1 = {"A","D","I","T","Y","A"}
set2 = {12,13,14,15,16}
set3 = {"aditya","anand","arun"}
set4 = {"big","small"}
largeset = set1.union(set2,set3,set4)
print(largeset)
# Out:
# {'T', 'D', 'Y', 'aditya', 'I', 12, 13, 14, 15, 16, 'arun', 'big', 'anand', 'A', 'small'}

# %%
set1 = {"A","D","I","T","Y","A"}
set2 = {12,13,14,15,16}
set3 = {"aditya","anand","arun"}
set4 = {"big","small"}
largeset = set1 |set2 |set3|set4
print(largeset)
# Out:
# {'T', 'D', 'Y', 'aditya', 'I', 12, 13, 14, 15, 16, 'arun', 'big', 'anand', 'A', 'small'}

# %%
set1 = {"A","D","I","T","Y","A"}
set2 = {12,13,14,15,16}
set1.update(set2)
print(set1)
# Out:
# {'T', 'D', 'Y', 'I', 12, 13, 14, 15, 16, 'A'}

# %%
set1 = {"A","D","I","T","Y","A"}
set2 = {12,13,14,15,16,"X"}
set3 = set1.intersection(set2)
print(set3)
# Out:
# set()

# %%
set1 = {"A","D","I","T","Y","A"}
set2 = {12,13,14,15,16}
set3 = set1&set2
print(set3)
# Out:
# set()

# %%
set1 = {"A","D","I","T","Y","A"}
set2 = {12,13,14,15,16}
set3 = set1.difference(set2)
print(set3)
# Out:
# {'T', 'D', 'Y', 'I', 'A'}

# %%
set1 = {"A","D","I","T","Y","A"}
set2 = {12,13,14,15,16}
set3 = set2.difference(set1)
print(set3)
# Out:
# {12, 13, 14, 15, 16}
